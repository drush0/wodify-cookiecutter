# %% [markdown]
# # {{cookiecutter.project_name}} - {% now 'America/New_York', '%m-%d-%Y' %}
#
# ### Description
# {{cookiecutter.description}}
#
# ### Changelog
# - {% now 'America/New_York', '%m-%d-%Y' %} -- Project Start

# %% [markdown]
# ## Import Packages

# %%
import os
import sys

module_path = os.path.abspath(os.path.join('../../'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
from wod_utils import wod_utils
import pandas as pd
import numpy as np

# %% [markdown]
# ## Read Data

# %%
sql = '''

'''
        
tmp = wod_utils.read_ms_sql(sql)

# %% [markdown]
# ## Process Data

# %%
df = tmp.copy()

df
